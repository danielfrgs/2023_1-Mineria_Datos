# %% [markdown]
# # <span style='color:blue'> <center>Knowledge Discovery in Data</center> </span>
# ## **Capítulo 1.** Manipulación de Datos con Pandas
# #### by **Ivan Alducin**
# <p><img src="https://cdn.datafloq.com/cache/blog_pictures/878x531/what-does-clustering-in-data-mining-mean.jpg" width="1250"></p>

# %% [markdown]
# ## Explorando un DataFrame
# <p>Cuando tenemos un nuevo DataFrame para trabajar, lo primero que debemos hacer es explorarlo y ver qué contiene.</p>

# %%
# Importar pandas
import pandas as pd

# %%
# Importar el archivo de sales a un DataFrame
sales = pd.read_csv('sales.csv')

# %%
# Imprimir las primeras 5 lineas de mi DataFrame
sales.head()
# Out:
#    store type  department        date  weekly_sales  is_holiday  temperature_c
# 0      1    A           1  05/02/2019      24924.50       False       5.727778
# 1      1    C           1  05/03/2019      21827.90       False       8.055556
# 2      1    A           1  02/04/2019      57258.43       False      16.816667
# 3      1    A           1  07/05/2019      17413.94       False      22.527778
# 4      1    A           1  04/06/2019      17558.09       False      27.050000

# %%
# Imprimir el tamaño (#filas, #columnas) de mi DataFrame
sales.size
# Out:
# 75418

# %% [markdown]
# ## Partes un DataFrame
# <p>Para comprender mejor la estructura de un DataFrame, es útil saber que constan de tres componentes, almacenados como atributos:
# <ul>
# <li><code>.values</code> muestra una matriz de valores NumPy bidimensional</li>
# <li><code>.columns</code> muestra índice de columnas: los nombres de las columnas.</li>
# <li><code>.index</code> muestra índice para las filas: números de fila o nombres de fila.</li>
# </ul>
# </p>

# %%
# Imprimir los valores de mi DataFrame

# %%
# Imprimir el nombre de mis campos (columnas) de mi DataFrame
sales.columns
# Out:
# Index(['store', 'type', 'department', 'date', 'weekly_sales', 'is_holiday',
#        'temperature_c'],
#       dtype='object')

# %%
# Imprimir el indice de mi DataFrame
sales.index
# Out:
# RangeIndex(start=0, stop=10774, step=1)

# %% [markdown]
# ## Ordenando filas de un DataFrame
# <p>Encontrar datos interesantes en un DataFrame suele ser más fácil si cambiamos el orden de las filas. Podemos ordenar las filas pasando un nombre de columna al método <code>.sort_values()</code>. </p>

# %%
# Ordena el DataFrame por el monto de venta semanal
sales.sort_values(by = 'weekly_sales')
# Out:
#       store type  department        date  weekly_sales  is_holiday  \
# 1420      2    A          47  30/07/2019      -1098.00       False
# 1422      2    A          47  15/10/2019      -1098.00       False
# 4115     10    B          47  15/10/2019       -798.00       False
# 4110     10    B          47  05/03/2019       -798.00       False
# 517       1    A          47  12/03/2019       -698.00       False
# ...     ...  ...         ...         ...           ...         ...
# 6237     14    A          95  05/02/2019     213042.66       False
# 6202     14    A          92  05/03/2019     214383.07       False
# 4281     10    B          72  03/12/2019     218559.54       False
# 4271     10    B          72  05/02/2019     232558.51       False
# 6201     14    A          92  05/02/2019     293966.05       False
#
#       temperature_c
# 1420      28.605556
# 1422      18.777778
# 4115      24.155556
# 4110      13.288889
# 517       14.327778
# ...             ...
# 6237      -2.605556
# 6202       2.850000
# 4281      10.650000
# 4271      12.411111
# 6201      -2.605556
#
# [10774 rows x 7 columns]

# %%
# Ordena el DataFrame por el monto de venta semanal de forma descendente
sales.sort_values(by = 'weekly_sales', ascending = True)
# Out:
#       store type  department        date  weekly_sales  is_holiday  \
# 1420      2    A          47  30/07/2019      -1098.00       False
# 1422      2    A          47  15/10/2019      -1098.00       False
# 4115     10    B          47  15/10/2019       -798.00       False
# 4110     10    B          47  05/03/2019       -798.00       False
# 517       1    A          47  12/03/2019       -698.00       False
# ...     ...  ...         ...         ...           ...         ...
# 6237     14    A          95  05/02/2019     213042.66       False
# 6202     14    A          92  05/03/2019     214383.07       False
# 4281     10    B          72  03/12/2019     218559.54       False
# 4271     10    B          72  05/02/2019     232558.51       False
# 6201     14    A          92  05/02/2019     293966.05       False
#
#       temperature_c
# 1420      28.605556
# 1422      18.777778
# 4115      24.155556
# 4110      13.288889
# 517       14.327778
# ...             ...
# 6237      -2.605556
# 6202       2.850000
# 4281      10.650000
# 4271      12.411111
# 6201      -2.605556
#
# [10774 rows x 7 columns]

# %%
# Ordena el Dataframe por depa y venta semanal de forma descendente
sales.sort_values(by = ['department', 'weekly_sales'], ascending = [True, False])
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 7201      20    A           1  02/04/2019     149743.97       False
# 5410      14    A           1  02/04/2019     148029.47       False
# 4497      13    A           1  02/04/2019     139870.90       False
# 3595      10    B           1  02/04/2019     131853.01       False
# 8111      27    A           1  02/04/2019      93213.63       False
# ...      ...  ...         ...         ...           ...         ...
# 8998      27    A          99  09/04/2019          0.01       False
# 9887      31    A          99  05/02/2019          0.01       False
# 10763     39    A          99  05/03/2019          0.01       False
# 10764     39    C          99  23/04/2019          0.01       False
# 1788       2    A          99  24/12/2019       -147.00       False
#
#        temperature_c
# 7201       10.555556
# 5410        8.744444
# 4497        5.638889
# 3595       17.588889
# 8111        8.277778
# ...              ...
# 8998       17.011111
# 9887        3.916667
# 10763      10.516667
# 10764      19.800000
# 1788        9.983333
#
# [10774 rows x 7 columns]

# %% [markdown]
# ## Filtrando un DataFrame
# <p>Una gran parte del proceso de análisis de datos consiste en encontrar qué partes de un conjunto de datos son interesantes. Una de las técnicas más simples para esto es encontrar un subconjunto de filas que coincida con algunos criterios.

# %%
# Filtra las filas donde las ventas sean negativas, ¿Porque crees que haya ventas negativas?
sales[sales['weekly_sales'] < 0]
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 517        1    A          47  12/03/2019       -698.00       False
# 519        1    A          47  08/10/2019        -58.00       False
# 522        1    A          47  08/07/2020       -198.00       False
# 1398       2    A          45  07/05/2019         -0.98       False
# 1420       2    A          47  30/07/2019      -1098.00       False
# ...      ...  ...         ...         ...           ...         ...
# 10112     39    A          19  08/04/2020         -9.97       False
# 10113     39    A          19  29/07/2020        -15.94       False
# 10405     39    A          47  11/03/2020        -15.00       False
# 10407     39    A          47  20/01/2021        -19.00       False
# 10566     39    A          77  09/12/2020       -159.00       False
#
#        temperature_c
# 517        14.327778
# 519        17.738889
# 522        29.905556
# 1398       21.822222
# 1420       28.605556
# ...              ...
# 10112      20.805556
# 10113      30.133333
# 10405      14.638889
# 10407      14.466667
# 10566       9.644444
#
# [108 rows x 7 columns]

# %%
# Filra las filas de las tiendas tipo A
sales[sales['type'] == 'A']
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  05/02/2019      24924.50       False
# 2          1    A           1  02/04/2019      57258.43       False
# 3          1    A           1  07/05/2019      17413.94       False
# 4          1    A           1  04/06/2019      17558.09       False
# 5          1    A           1  02/07/2019      16333.14       False
# ...      ...  ...         ...         ...           ...         ...
# 10768     39    A          99  11/11/2020         50.00       False
# 10770     39    A          99  03/02/2021        350.00       False
# 10771     39    A          99  08/06/2021        450.00       False
# 10772     39    A          99  13/07/2021          0.06       False
# 10773     39    A          99  05/10/2021        915.00       False
#
#        temperature_c
# 0           5.727778
# 2          16.816667
# 3          22.527778
# 4          27.050000
# 5          27.172222
# ...              ...
# 10768      17.283333
# 10770      15.938889
# 10771      27.288889
# 10772      25.644444
# 10773      22.250000
#
# [9766 rows x 7 columns]

# %%
# Filra las filas de las tiendas tipo A y C
sales[(sales['type'] == 'A') | (sales['type'] == 'C') ]
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  05/02/2019      24924.50       False
# 1          1    C           1  05/03/2019      21827.90       False
# 2          1    A           1  02/04/2019      57258.43       False
# 3          1    A           1  07/05/2019      17413.94       False
# 4          1    A           1  04/06/2019      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    C          99  09/12/2020        895.00       False
# 10770     39    A          99  03/02/2021        350.00       False
# 10771     39    A          99  08/06/2021        450.00       False
# 10772     39    A          99  13/07/2021          0.06       False
# 10773     39    A          99  05/10/2021        915.00       False
#
#        temperature_c
# 0           5.727778
# 1           8.055556
# 2          16.816667
# 3          22.527778
# 4          27.050000
# ...              ...
# 10769       9.644444
# 10770      15.938889
# 10771      27.288889
# 10772      25.644444
# 10773      22.250000
#
# [9872 rows x 7 columns]

# %%
# Filra las filas de las tiendas 1, 2, 10, 20 y 31

stores = [1, 2, 10, 20, 31]

sales[sales['store'].isin(stores)]
# Out:
#       store type  department        date  weekly_sales  is_holiday  \
# 0         1    A           1  05/02/2019      24924.50       False
# 1         1    C           1  05/03/2019      21827.90       False
# 2         1    A           1  02/04/2019      57258.43       False
# 3         1    A           1  07/05/2019      17413.94       False
# 4         1    A           1  04/06/2019      17558.09       False
# ...     ...  ...         ...         ...           ...         ...
# 9894     31    A          99  02/09/2020         60.04       False
# 9895     31    A          99  07/10/2020          0.05       False
# 9896     31    A          99  11/11/2020        125.01       False
# 9897     31    A          99  09/12/2020        285.00       False
# 9898     31    A          99  20/01/2021          0.02       False
#
#       temperature_c
# 0          5.727778
# 1          8.055556
# 2         16.816667
# 3         22.527778
# 4         27.050000
# ...             ...
# 9894      33.300000
# 9895      22.022222
# 9896      15.444444
# 9897       5.244444
# 9898      11.227778
#
# [4500 rows x 7 columns]

# %% [markdown]
# ## Agregando nuevas columnas
# <p>Por lo general los datos que tenemos no son suficientes para nuestro análisis, siempre necesitamos agregar nuevas columnas o campos calculados a nuestro DataFrame. Esto en el campo de la ciencia de datos se le conoce como <i>feature engineering</i>.
# Se pueden crear nuevas columnas desde cero, pero también es común derivarlas de otras, por ejemplo, agregando campos calculados con base en otro existente o cambiando su escala de unidades o valor.

# %%
# Crear una columna que calcule el precio de venta + IVA
sales['iva'] = sales['weekly_sales'] * 1.16
sales
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  05/02/2019      24924.50       False
# 1          1    C           1  05/03/2019      21827.90       False
# 2          1    A           1  02/04/2019      57258.43       False
# 3          1    A           1  07/05/2019      17413.94       False
# 4          1    A           1  04/06/2019      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    C          99  09/12/2020        895.00       False
# 10770     39    A          99  03/02/2021        350.00       False
# 10771     39    A          99  08/06/2021        450.00       False
# 10772     39    A          99  13/07/2021          0.06       False
# 10773     39    A          99  05/10/2021        915.00       False
#
#        temperature_c         iva
# 0           5.727778  28912.4200
# 1           8.055556  25320.3640
# 2          16.816667  66419.7788
# 3          22.527778  20200.1704
# 4          27.050000  20367.3844
# ...              ...         ...
# 10769       9.644444   1038.2000
# 10770      15.938889    406.0000
# 10771      27.288889    522.0000
# 10772      25.644444      0.0696
# 10773      22.250000   1061.4000
#
# [10774 rows x 8 columns]

# %% [markdown]
# ## Funciones estadísticas
# <p><i>Summary statistics</i> o la estadística de resumen es el conjunto de medidas cuantitativas que nos permiten visualizar el comportamiento de una variable. Por ejemplo, la desviación media, mediana, mínimo, máxima y estándar son estadísticas de resumen. El cálculo de estas nos permite tener una mejor comprensión y entendimiento de nuestro conjunto de datos, incluso si es muy grande.</p>

# %%
# Calcular el promedio de las venta semanales
sales['weekly_sales'].mean()
# Out:
# 23843.95014850566

# %%
# Calcular la mediana de las ventas semanales
sales['weekly_sales'].median()
# Out:
# 12049.064999999999

# %%
# Imprimir la estadística descriptiva básica de mi DataFrame
sales.describe()
# Out:
#               store    department   weekly_sales  temperature_c            iva
# count  10774.000000  10774.000000   10774.000000   10774.000000   10774.000000
# mean      15.441897     45.218118   23843.950149      15.731978   27658.982172
# std       11.534511     29.867779   30220.387557       9.922446   35055.649566
# min        1.000000      1.000000   -1098.000000      -8.366667   -1273.680000
# 25%        4.000000     20.000000    3867.115000       7.583333    4485.853400
# 50%       13.000000     40.000000   12049.065000      16.966667   13976.915400
# 75%       20.000000     72.000000   32349.850000      24.166667   37525.826000
# max       39.000000     99.000000  293966.050000      33.827778  341000.618000

# %%
sales.hist('weekly_sales')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f50b706c810>]],
#       dtype=object)

# %%
sales['date'] = sales['date'].astype('datetime64[ns]')
# Calcular la última fecha de venta

# %%
sales['date'].max()
# Out:
# Timestamp('2021-12-10 00:00:00')

# %%
# Calcular la fecha en la que tuve mi primer venta
sales['date'].min()
# Out:
# Timestamp('2019-01-10 00:00:00')

# %% [markdown]
# ## Multiples funciones
# <p>El método <code>.agg()</code> nos permite aplicar nuestras propias funciones personalizadas a un DataFrame, así como también aplicar funciones a más de una columna a la vez, lo que hace que los cálculos sean súper eficientes. Lo anterior se hace usando la siguiente nomenclatura: <code>df['columna'].agg([funcion1, funcion2])</code>

# %%
# Calcula la media para las ventas y la temperatura
sales[['weekly_sales', 'temperature_c']].mean()
# Out:
# weekly_sales     23843.950149
# temperature_c       15.731978
# dtype: float64

# %%
# Agrega la mediana y el máximo al cálculo anterior
sales[['weekly_sales', 'temperature_c']].agg(['mean', 'median'])
# Out:
#         weekly_sales  temperature_c
# mean    23843.950149      15.731978
# median  12049.065000      16.966667

# %%
# Crea un nuevo DataFrame que contenga las ventas de la tienda 1 y el departamento 1
sales_1_1 = sales[(sales['department'] == 1) & (sales['store'] == 1)]
sales_1_1
# Out:
#     store type  department       date  weekly_sales  is_holiday  \
# 0       1    A           1 2019-05-02      24924.50       False
# 1       1    C           1 2019-05-03      21827.90       False
# 2       1    A           1 2019-02-04      57258.43       False
# 3       1    A           1 2019-07-05      17413.94       False
# 4       1    A           1 2019-04-06      17558.09       False
# 5       1    A           1 2019-02-07      16333.14       False
# 6       1    A           1 2019-06-08      17508.41       False
# 7       1    C           1 2019-03-09      16241.78       False
# 8       1    A           1 2019-01-10      20094.19       False
# 9       1    A           1 2019-05-11      34238.88       False
# 10      1    A           1 2019-03-12      22517.56       False
# 11      1    A           1 2020-07-01      15984.24       False
#
#     temperature_c         iva
# 0        5.727778  28912.4200
# 1        8.055556  25320.3640
# 2       16.816667  66419.7788
# 3       22.527778  20200.1704
# 4       27.050000  20367.3844
# 5       27.172222  18946.4424
# 6       30.644444  20309.7556
# 7       27.338889  18840.4648
# 8       22.161111  23309.2604
# 9       14.855556  39717.1008
# 10       9.594444  26120.3696
# 11       9.038889  18541.7184

# %%
# Ordena por fecha
sales_1_1.sort_values('date', inplace = True)

# Crea un nuevo campo calculando la venta acumulada semanal
sales_1_1['cum_weekly_sales'] = sales_1_1['weekly_sales'].cumm()

# Crea un nuevo campo campo calculado con la venta acumulada máxima
sales_1_1['cum_max_sales'] = sales_1_1['weekly_sales'].cummax()

# Vamos a ver los campos que acabas de crear
print(sales_1_1[["date", "weekly_sales", "cum_weekly_sales", "cum_max_sales"]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-a3a832f2d7ab> in <module>
#       9
#      10 # Vamos a ver los campos que acabas de crear
# ---> 11 print(sales_1_1[["date", "weekly_sales", "cum_weekly_sales", "cum_max_sales"]])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['cum_weekly_sales'] not in index"

# %% [markdown]
# ## Eliminando duplicados de un DataFrame
# <p>Eliminar duplicados es una habilidad esencial para obtener análisis precisos porque, a menudo, no deseamos tener valores repetidos dentro de nuestros cálculos.</p>

# %%
# Elimina los duplicados de las combinaciones store/type
store_types = sales.drop_duplicates(subset=['store', 'department'])
store_types
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1 2019-05-02      24924.50       False
# 12         1    A           2 2019-05-02      50605.27       False
# 24         1    A           3 2019-05-02      13740.12       False
# 36         1    A           4 2019-05-02      39954.04       False
# 48         1    A           5 2019-05-02      32229.38       False
# ...      ...  ...         ...        ...           ...         ...
# 10715     39    A          95 2019-05-02      88385.24       False
# 10727     39    A          96 2019-05-02      21450.05       False
# 10739     39    A          97 2019-05-02      21162.05       False
# 10751     39    A          98 2019-05-02       9023.09       False
# 10763     39    A          99 2019-05-03          0.01       False
#
#        temperature_c          iva
# 0           5.727778   28912.4200
# 12          5.727778   58702.1132
# 24          5.727778   15938.5392
# 36          5.727778   46346.6864
# 48          5.727778   37386.0808
# ...              ...          ...
# 10715       6.833333  102526.8784
# 10727       6.833333   24882.0580
# 10739       6.833333   24547.9780
# 10751       6.833333   10466.7844
# 10763      10.516667       0.0116
#
# [929 rows x 8 columns]

# %%
# Elimina los duplicados de las combinaciones store/department y ordena por venta semanal
store_depts = sales.drop_duplicates(subset=['type', 'department']).sort_values('weekly_sales')
store_depts
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 4109      10    B          47 2019-02-19          0.00       False
# 10764     39    C          99 2019-04-23          0.01       False
# 890        1    A          99 2019-02-07          0.01       False
# 1345       2    C          39 2019-02-19          0.78       False
# 1346       2    A          39 2019-05-03          0.78       False
# ...      ...  ...         ...        ...           ...         ...
# 432        1    A          38 2019-05-02     115564.35       False
# 4037      10    B          40 2019-05-02     119463.15       False
# 3605      10    B           2 2019-05-02     123952.48       False
# 806        1    A          92 2019-05-02     139884.94       False
# 4271      10    B          72 2019-05-02     232558.51       False
#
#        temperature_c          iva
# 4109       14.566667       0.0000
# 10764      19.800000       0.0116
# 890        27.172222       0.0116
# 1345        4.272222       0.9048
# 1346        8.427778       0.9048
# ...              ...          ...
# 432         5.727778  134054.6460
# 4037       12.411111  138577.2540
# 3605       12.411111  143784.8768
# 806         5.727778  162266.5304
# 4271       12.411111  269767.8716
#
# [215 rows x 8 columns]

# %%
# Filtra las filas en donde las ventas hayan sido en días festivos ('is_holiday') y borra los duplicados de las fechas
holiday_dates = sales[sales['is_holiday'] == True].drop_duplicates(subset=['date'])
holiday_dates
# Out:
#       store type  department       date  weekly_sales  is_holiday  \
# 498       1    A          45 2019-10-09         11.47        True
# 691       1    A          77 2020-11-25       1431.00        True
# 2315      4    A          47 2019-12-02        498.00        True
# 6735     19    A          39 2021-07-09         13.41        True
# 6810     19    A          47 2019-12-31       -449.00        True
# 6815     19    A          47 2021-10-02         15.00        True
# 6820     19    A          48 2020-09-09        197.00        True
#
#       temperature_c        iva
# 498       25.938889    13.3052
# 691       15.633333  1659.9600
# 2315      -1.755556   577.6800
# 6735      22.333333    15.5556
# 6810      -1.861111  -520.8400
# 6815       0.338889    17.4000
# 6820      20.155556   228.5200

# %% [markdown]
# ## Conteo y proporción
# <p>Contar es una excelente manera de obtener una descripción general de nuestro conjunto datos y poder analizar sobre todo nuestras categorías top o en su defecto las que menor proporción tienen con respecto una variable</p>

# %%
# Contar el número de transacciones de cada tipo de tiendas

# %%
# Dar la proporcion del cálculo anterior

# %% [markdown]
# ## Porcentaje de ventas
# <p>Walmart distingue tres tipos de tiendas: "supercenters", "discount stores" y "neighborhood markets", codificados en este conjunto de datos como tipo "A", "B" y "C". En este ejercicio, vamos a calcular las ventas totales realizadas en cada tipo de tienda, sin utilizar <code>.groupby()</code>.</p>

# %%
# Calcular el total de ventas semanales
sales_all = 

# Calcular las ventas semanales para supercenters
sales_A = 

# Calcular las ventas semanales para discount stores
sales_B = 

# Calcular las ventas semanales para neighborhood markets
sales_C = 

# Calcular la proporción de venta por tipo de tienda
sales_propn_by_type =

# %% [markdown]
# ## Group by
# <p> Podemos ahorrarnos mucho código usando el método <code>.groupby</code> como veremos a continuación</p>

# %%
# Calcular las ventas por tipo de tienda usando .groupby()
sales_by_type =

# %%
# Calcular la proporción de ventas por tipo de tienda
sales_prop = ____ / ____

# Resultado
print("La proporcion de venta por tienda es: " ____)

# %%
# Para cada tipo de tienda calcular la venta mínima, máxima, media y la mediana

# %%
# Para cada tipo de tienda, agrega la temperatura y calcula el minimo, maximo, media y mediana

# %% [markdown]
# ## Pivot Tables
# <p> Las tablas dinámicas son la forma estándar de agregar datos en hojas de cálculo. En pandas, las tablas dinámicas son esencialmente otra forma de realizar cálculos agrupados. Es decir, el método <code>.pivot_table()</code> es justamente una alternativa a <code>.groupby()</code>.</p>

# %%
# Calcular el promedio de ventas semanales por tipo de tienda con el metodo .pivot_table()

# %%
# Calcular el promedio y la mediana de ventas semanales por tipo de tienda

# %%
# Calcular el promedio de ventas semanales por tipo de tienda y departamento

# %%
# Calcular el promedio de ventas semanales por tipo de tienda y departamento, reemplazando los valores nulos con 0

# %%
# Calcular el promedio de ventas semanales por tipo de tienda y departamento, reemplazando los valores nulos con 0 y sumando las filas y columnas

# %%
# Exporta tu resultado a un csv
